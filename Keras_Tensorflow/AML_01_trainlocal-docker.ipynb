# %%
# Check core SDK version number
import azureml.core

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 0.1.4

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Found the config file in: /home/jayaubuntudsvm/Desktop/AKSDeploymentTutorial/Keras_Tensorflow/aml_config/config.json
# jayavienna
# jayavienna
# eastus2
# edf507a2-6235-46c5-b560-fd463ba2e771

# %%
# choose a name for the run history container in the workspace
run_history_name = 'train-on-local'

# project folder
project_folder = './sample_projects/train-on-local'

# %%
import os
from azureml.core import Project

project = Project.attach(workspace_object = ws,
                         history_name = run_history_name,
                         directory = project_folder)

print(project.project_directory, project.history.name, sep = '\n')
# Out:
# /home/jayaubuntudsvm/Desktop/AKSDeploymentTutorial/Keras_Tensorflow/sample_projects/train-on-local
# train-on-local

# %%
# %%writefile $project_folder/train.py

#Develop the model

import tensorflow as tf
import keras
from resnet152 import ResNet152
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
import numpy as np
from PIL import Image
import wget

model = ResNet152(weights='imagenet')

#model.summary( )

wget.download('https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/Lynx_lynx_poing.jpg/220px-Lynx_lynx_poing.jpg')

img_path = '220px-Lynx_lynx_poing.jpg'
#print(Image.open(img_path).size)
Image.open(img_path)

img = image.load_img(img_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

preds = model.predict(img)
print('Predicted:', decode_predictions(preds, top=3))
# Out:
# Overwriting ./sample_projects/train-on-local/train.py

# %%
#User-managed runs

from azureml.core.runconfig import RunConfiguration

# Editing a run configuration property on-fly.
run_config = RunConfiguration.load(project_object = project, run_config_name = "local")

run_config.environment.python.user_managed_dependencies = True
run_config.prepare_environment = True

# You can choose a specific Python environment by pointing to a Python path 
#run_config.environment.python.interpreter_path = '/home/ninghai/miniconda3/envs/sdk2/bin/python'

# %%
# %%time 
from azureml.core.run import Run

run = Run.submit(project_object = project,
                 run_config = run_config,
                 script_to_run = 'train.py')

# Shows output of the run on stdout.
run.wait_for_completion(show_output = True)
# Out:
# RunId: train-on-local_1536091846
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# Warning: Unable to import azureml.history. Output collection disabled.
# /anaconda/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-09-04 20:10:48.477611: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-04 20:10:48.621588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 6f0b:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-09-04 20:10:48.621627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1435] Adding visible gpu devices: 0
# 2018-09-04 20:10:48.872163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:923] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-04 20:10:48.872205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:929]      0
# 2018-09-04 20:10:48.872214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:942] 0:   N
# 2018-09-04 20:10:48.872462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1053] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 6f0b:00:00.0, compute capability: 3.7)
# Predicted: [[('n02127052', 'lynx', 0.9959085), ('n02128385', 'leopard', 0.0011504446), ('n02123159', 'tiger_cat', 0.0009417986)]]
# The experiment completed successfully. Starting post-processing steps.
#
# Execution Summary
# =================
# RunId: train-on-local_1536091846
#
# CPU times: user 920 ms, sys: 65.5 ms, total: 985 ms
# Wall time: 41.2 s

# %%
# make sure you have helpers.py in the current folder
import helpers
print(helpers.get_run_history_url(run))
# Out:
# https://mlworkspace.azureml-test.net/portal/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/jayavienna/providers/Microsoft.MachineLearningServices/workspaces/jayavienna/history/train-on-local/runs/train-on-local_1536091846

# %%
# Docker based execution

from azureml.core.conda_dependencies import CondaDependencies

# Editing a run configuration property on-fly.
run_config = RunConfiguration.load(project_object = project, run_config_name = "local")

# enable Docker
run_config.environment.docker.enabled = True
print("base image to user:", run_config.environment.docker.base_image)

# Build a new conda environment from the conda_dependencies.yml file inside of the Docker container
run_config.environment.python.user_managed_dependencies = False

# Automatically create the conda environment before the run
run_config.prepare_environment = True

# add additional packages to the conda_dependencies.yml file

#cd = CondaDependencies()
#cd.add_conda_package('tensorflow==1.9.0')
#cd.add_pip_package(‘a_pip_pkg_that_cannot_be_installed_via_conda’)
#runconfig = RunConfig(conda_dependencies=cd)

cd = CondaDependencies()
cd.add_conda_package('python=3.6')
cd.add_conda_package('tensorflow')
cd.add_conda_package('tornado==4.5.3')

cd.add_pip_package('papermill==0.14.1')
cd.add_pip_package('python-dotenv==0.9.0')
cd.add_pip_package('Pillow==5.2.0')
cd.add_pip_package('wget==3.2')
cd.add_pip_package('aiohttp==3.3.2')
cd.add_pip_package('toolz==0.9.0')
cd.add_pip_package('tqdm==4.23.4')
cd.add_pip_package('azure-cli==2.0.41')
#cd.add_pip_package('tensorflow')
cd.add_pip_package('keras==2.2.0')

cd.save_to_file(project_dir = project_folder, conda_file_path = run_config.environment.python.conda_dependencies_file)
# Out:
# base image to user: continuumio/miniconda3:4.4.10
# 'aml_config/conda_dependencies.yml'

# %%
# %%time 
print("Submitting an experiment.")
run = Run.submit(project_object = project,
                 run_config = run_config, 
                 script_to_run = "train.py")

# Shows output of the run on stdout.
run.wait_for_completion(show_output = True)
# Out:
# Submitting an experiment.
# RunId: train-on-local_1536091959
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Uploading experiment status to history service.
# Adding run profile attachment azureml-logs/60_control_log.txt
# Logging experiment preparation status in history service.
# Running: ['sudo', 'docker', 'build', '-f', 'azureml-setup/Dockerfile', '-t', 'azureml/azureml_bce24304934b364a91b9452e2beac9e2', '.']
# Sending build context to Docker daemon  205.8kB
# Step 1/13 : FROM continuumio/miniconda3:4.4.10
#  ---> bfb745918f77
# Step 2/13 : USER root
#  ---> Using cache
#  ---> 3a0dd622d249
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Using cache
#  ---> bd9dfd8ddbe8
# Step 4/13 : WORKDIR /
#  ---> Using cache
#  ---> c7d6c938ec39
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> Using cache
#  ---> e11a753a8158
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11 -c anaconda; fi
#  ---> Using cache
#  ---> 4707ded2ba8f
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> c3751c6b8191
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63 -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in a94c1a57bbb3
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
# python 3.6.6: ########## | 100%
# tensorboard 1.9.0: ########## | 100%
# blas 1.0: ########## | 100%
# readline 7.0: ########## | 100%
# sqlite 3.24.0: ########## | 100%
# tensorflow-base 1.9.0: ########## | 100%
# mkl_fft 1.0.4: ########## | 100%
# numpy-base 1.15.1: ########## | 100%
# libprotobuf 3.6.0: ########## | 100%
# markdown 2.6.11: ########## | 100%
# gast 0.2.0: ########## | 100%
# werkzeug 0.14.1: ########## | 100%
# six 1.11.0: ########## | 100%
# mkl_random 1.0.1: ########## | 100%
# libstdcxx-ng 8.2.0: ########## | 100%
# openssl 1.0.2p: ########## | 100%
# astor 0.7.1: ########## | 100%
# pip 10.0.1: ########## | 100%
# xz 5.2.4: ########## | 100%
# tk 8.6.8: ########## | 100%
# ca-certificates 2018.03.07: ########## | 100%
# termcolor 1.1.0: ########## | 100%
# certifi 2018.8.24: ########## | 100%
# setuptools 40.2.0: ########## | 100%
# intel-openmp 2018.0.3: ########## | 100%
# mkl 2018.0.3: ########## | 100%
# protobuf 3.6.0: ########## | 100%
# wheel 0.31.1: ########## | 100%
# libgcc-ng 8.2.0: ########## | 100%
# libgfortran-ng 7.3.0: ########## | 100%
# libedit 3.1.20170329: ########## | 100%
# absl-py 0.4.0: ########## | 100%
# numpy 1.15.1: ########## | 100%
# grpcio 1.12.1: ########## | 100%
# tornado 4.5.3: ########## | 100%
# tensorflow 1.9.0: ########## | 100%
# _tflow_190_select 0.0.3: ########## | 100%
# ncurses 6.1: ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Looking in indexes: https://azuremlsdktestpypi.azureedge.net/sdk-release/Preview/E7501C02541B433786111FE8E140CAA1, https://pypi.python.org/simple
# Collecting azureml-defaults (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/sdk-release/Preview/E7501C02541B433786111FE8E140CAA1/azureml_defaults-0.1.4-py2.py3-none-any.whl?sv=2017-04-17&sr=b&sig=tFylh97HT%2BKHVX8CnS7eU9Yq9izl6ecq6%2FFMiiy3Jv8%3D&st=2018-08-17T19%3A28%3A41Z&se=2019-08-17T19%3A28%3A41Z&sp=rl
# Collecting papermill==0.14.1 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/df/84/e7d7b5ad7f8545df04762fbbbb30e404a21e2f53235fec31a393b75f3879/papermill-0.14.1-py2.py3-none-any.whl
# Collecting python-dotenv==0.9.0 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/b0/7e/00daf9870818a31fca9027635dad73a87be892616bb4a108e32cade8738c/python_dotenv-0.9.0-py2.py3-none-any.whl
# Collecting Pillow==5.2.0 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 6))
#   Downloading https://files.pythonhosted.org/packages/d1/24/f53ff6b61b3d728b90934bddb4f03f8ab584a7f49299bf3bde56e2952612/Pillow-5.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
# Collecting wget==3.2 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Collecting aiohttp==3.3.2 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/54/f9/8b47199ceae89a867edc45c43dc908384fd2e1ac22406b60d101d988752b/aiohttp-3.3.2-cp36-cp36m-manylinux1_x86_64.whl (876kB)
# Collecting toolz==0.9.0 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/14/d0/a73c15bbeda3d2e7b381a36afb0d9cd770a9f4adc5d1532691013ba881db/toolz-0.9.0.tar.gz (45kB)
# Collecting tqdm==4.23.4 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/93/24/6ab1df969db228aed36a648a8959d1027099ce45fad67532b9673d533318/tqdm-4.23.4-py2.py3-none-any.whl (42kB)
# Collecting azure-cli==2.0.41 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ec/f8/4e0928c8b64febd13b3cff2556a4b9deb90db90188cb88c6396a718fbf5d/azure_cli-2.0.41-py2.py3-none-any.whl
# Collecting keras==2.2.0 (from -r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/68/12/4cabc5c01451eb3b413d19ea151f36e33026fc0efb932bf51bcaf54acbf5/Keras-2.2.0-py2.py3-none-any.whl (300kB)
# Collecting applicationinsights>=0.11.0 (from azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/cc/2d/d4db42d661c8a2ebd25bbbff7513ba3604ce11c1e76f9543543de1754f44/applicationinsights-0.11.6-py2.py3-none-any.whl (55kB)
# Collecting azureml-core==0.1.4 (from azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/sdk-release/Preview/E7501C02541B433786111FE8E140CAA1/azureml_core-0.1.4-py2.py3-none-any.whl?sv=2017-04-17&sr=b&sig=0%2B%2F7kV3%2B%2BUs3LtlT0i2z13pnnrhYYkWHIcU5mAYW2nI%3D&st=2018-08-17T19%3A28%3A41Z&se=2019-08-17T19%3A28%3A41Z&sp=rl (724kB)
# Collecting jupyter-client (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/94/dd/fe6c4d683b09eb05342bd2816b7779663f71762b4fa9c2d5203d35d17354/jupyter_client-5.2.3-py2.py3-none-any.whl (89kB)
# Collecting ansiwrap (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/e7/99/aa9e375148c9a03bc7d76eb60993eaf2a04fcaf804f3547c4ca6bdeaef28/ansiwrap-0.8.3-py2.py3-none-any.whl
# Collecting boto3 (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/a8/45/810f786ce144bfd19d9f2f700a8cd4358435559a2b88b2c235f7bb3f29df/boto3-1.8.6-py2.py3-none-any.whl (128kB)
# Collecting pyyaml (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
# Requirement already satisfied: six in /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib/python3.6/site-packages (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4)) (1.11.0)
# Collecting pandas (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/e1/d8/feeb346d41f181e83fba45224ab14a8d8af019b48af742e047f3845d8cff/pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9MB)
# Collecting click (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/34/c1/8806f99713ddb993c5366c362b2f908f18269f8d792aff1abfd700775a77/click-6.7-py2.py3-none-any.whl (71kB)
# Collecting nbformat (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl (155kB)
# Collecting nbconvert (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/39/ea/280d6c0d92f8e3ca15fd798bbcc2ea141489f9539de7133d8fe10ea4b049/nbconvert-5.3.1-py2.py3-none-any.whl (387kB)
# Collecting requests (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/65/47/7e02164a2a3db50ed6d8a6ab1d6d60b69c4c3fdf57a284257925dfc12bda/requests-2.19.1-py2.py3-none-any.whl (91kB)
# Collecting ipython>=5.0 (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/f7/62/2fef7db3a7b75e8099c3d9db2630ae5ba0b9eefefd91f7497862393d90e8/ipython-6.5.0-py3-none-any.whl (748kB)
# Collecting future (from papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
# Collecting attrs>=17.3.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/3a/e1/5f9023cc983f1a628a8c2fd051ad19e76ff7b142a0faf329336f9a62a514/attrs-18.2.0-py2.py3-none-any.whl
# Collecting async-timeout<4.0,>=3.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/96/0f/e6357458c87fb4ed8f3df215773f3caad40968f10e05552cbd8bd28415e4/async_timeout-3.0.0-py3-none-any.whl
# Collecting chardet<4.0,>=2.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/61/67/df71b367680e06bb4127e3df6189826d4b9daebf83c3bd5b9341c99ef528/yarl-1.2.6-cp36-cp36m-manylinux1_x86_64.whl (253kB)
# Collecting multidict<5.0,>=4.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/a3/92/00de45dc04830f8c715bcfbf96f6e531b26d564d7bff63ba92e7c459c82a/multidict-4.4.0-cp36-cp36m-manylinux1_x86_64.whl (385kB)
# Collecting idna-ssl>=1.0 (from aiohttp==3.3.2->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting azure-cli-redis (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/eb/e1/0bd4413814f8e0b7a18e269815afb2ebf999c2571f6e054e134428a5f706/azure_cli_redis-0.3.2-py2.py3-none-any.whl
# Collecting azure-cli-cloud (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/77/75/196b4456addad2bd3a738e036a00b9d27455590bc807f7218751f9f0b4eb/azure_cli_cloud-2.1.0-py2.py3-none-any.whl
# Collecting azure-cli-cdn (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/80/20/02fd179a36abbcc056e17065d3d2314ae930de62468f5d63240fefabcb20/azure_cli_cdn-0.1.1-py2.py3-none-any.whl
# Collecting azure-cli-feedback (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d5/00/629340da085c8f43d4552b26fa9acaa13fd817c7ba050228d8b9427a2844/azure_cli_feedback-2.1.4-py2.py3-none-any.whl
# Collecting azure-cli-consumption (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/f4/05/8f9fc7981f901ff9c886fd5b76fa304ef92a7f675fd14323b42b53420f90/azure_cli_consumption-0.4.0-py2.py3-none-any.whl
# Collecting azure-cli-eventgrid (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/f7/31/c4eec7519ce93bdf490a4fc171e12f8201d986ff8075772cd8d3103b0a3d/azure_cli_eventgrid-0.2.0-py2.py3-none-any.whl
# Collecting azure-cli-monitor (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/22/6b/87a551ade5426062acdd1bd0e26507eeabfdd72010377f60f68b87fb8f63/azure_cli_monitor-0.2.3-py2.py3-none-any.whl (52kB)
# Collecting azure-cli-eventhubs (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/24/fd/e0c961ac6a5b59bf5e1d44b4578ac11a04ab57133bc765c6ac6ef1a817b7/azure_cli_eventhubs-0.2.3-py2.py3-none-any.whl
# Collecting azure-cli-find (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/0c/5a/4a6a5378c7a86c3099670e2863a263ecec0eb58a3d4a50ba04bbe99cef18/azure_cli_find-0.2.12-py2.py3-none-any.whl
# Collecting azure-cli-storage (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/28/ad/86de0d4de8db4aec3ab7b26ba3ddba1db1e10b98c70392b4133c8de69930/azure_cli_storage-2.2.1-py2.py3-none-any.whl (58kB)
# Collecting azure-cli-network (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d5/fb/efa15609bb5167460eac4795e5494709315ce70556ced164cbbce5ae2447/azure_cli_network-2.2.4-py2.py3-none-any.whl (100kB)
# Collecting azure-cli-servicebus (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/8e/1d/a5a2c3b0c076c2e2a4f790d955d8c1de3fa17a1ff9d0027fa7bc03f264bc/azure_cli_servicebus-0.2.2-py2.py3-none-any.whl
# Collecting azure-cli-configure (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/b2/98/12635047be40142cb13d44917abed3fd836d2690799fc4e0bfd4367c8893/azure_cli_configure-2.0.18-py2.py3-none-any.whl
# Collecting azure-cli-iot (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/dd/f1/c84764c33f1f502beaa095ab8e5e2ec5edcdcfb616fba21ae21de4b822b1/azure_cli_iot-0.3.1-py2.py3-none-any.whl
# Collecting azure-cli-acr (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/53/0a/77a13e99f0b3a463f879f11a2daf9e91f0b56207efba0e60d40280fa4021/azure_cli_acr-2.1.4-py2.py3-none-any.whl (46kB)
# Collecting azure-cli-acs (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/67/d7/63aeda64634e63b9b533f0c05701b54a1fdd895f3bbb9c1640cb5303c1db/azure_cli_acs-2.3.2-py2.py3-none-any.whl (45kB)
# Collecting azure-cli-profile (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/f1/70/642eb54b3f33b90c47acdb777a5f9613ff7904abf15216cb4a164f586160/azure_cli_profile-2.1.1-py2.py3-none-any.whl
# Collecting azure-cli-billing (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/0c/1a/e2d253d4c3c56395959643ebcb575afafd1653db6243126b7c76b76502e4/azure_cli_billing-0.2.0-py2.py3-none-any.whl
# Collecting azure-cli-dms (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/05/39/5125d12955f8253f86e577fc22e72a6295b7a05163c1415f80820de3448c/azure_cli_dms-0.1.0-py2.py3-none-any.whl
# Collecting azure-cli-rdbms (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/80/15/dc2fcb850a7b16370be3e8f7a0c79f0f196e0803c8f4c5cf20fd83a473e2/azure_cli_rdbms-0.3.1-py2.py3-none-any.whl
# Collecting azure-cli-extension (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/3a/95/266c37f834299ef3da2e29253e9ed2d5b0a29a3ef1938978ab690a57682e/azure_cli_extension-0.2.1-py2.py3-none-any.whl
# Collecting azure-cli-vm (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/5e/f7/f7e961329f97a02b03181eee975af8abff3d44d48e9deefdd8399b6072bd/azure_cli_vm-2.2.2-py2.py3-none-any.whl (92kB)
# Collecting azure-cli-dls (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d2/68/416d0341e6e2f3da3794c7226c05ae8ccb9dcfbf29b8c50a1db56b2e6c9a/azure_cli_dls-0.1.1-py2.py3-none-any.whl
# Collecting azure-cli-nspkg (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting azure-cli-cosmosdb (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/42/10/e3c82c23513ecdf406cfe49634d8a565a88e7582a82f7130c273febf9cd9/azure_cli_cosmosdb-0.2.1-py2.py3-none-any.whl
# Collecting azure-cli-appservice (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/99/74/2795803e8afe5e2ca676d3a786954865ca3b9a457eb2fdf359752d73854f/azure_cli_appservice-0.2.3-py2.py3-none-any.whl (41kB)
# Collecting azure-cli-backup (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/f2/6d/83aeb520dab78dbaeb396cb7cfd713365117aa0fc064018c1ec45be2b549/azure_cli_backup-1.2.1-py2.py3-none-any.whl
# Collecting azure-cli-servicefabric (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d2/81/6db9a091ef0cd1c0f9ba7625188e4f6f16c6431d491f7ee3618dfe487e43/azure_cli_servicefabric-0.1.2-py2.py3-none-any.whl
# Collecting azure-cli-core (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/9d/f5/169365ce6f81da0bd6ee64f38bd1978e5876f0cb4ec5d6eb632b4b011e1f/azure_cli_core-2.0.45-py2.py3-none-any.whl (96kB)
# Collecting azure-cli-resource (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/c2/ec/448f7eba311eb5b0a2a5c58d7abc4ca462d552da24bcfa7acd0b8c6f7be6/azure_cli_resource-2.1.3-py2.py3-none-any.whl
# Collecting azure-cli-sql (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/2c/a2/b5f804d9377ea3206230189329c2f2411c20b2091daded906f16d262a429/azure_cli_sql-2.1.3-py2.py3-none-any.whl
# Collecting azure-cli-reservations (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/2d/5e/b4230ce63ca29ac0f15ffbf952aaaa23f9d4b8d1a8452df611d1bbf53fa5/azure_cli_reservations-0.3.2-py2.py3-none-any.whl
# Collecting azure-cli-ams (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/6f/fe/e654dbbfadbc95968e22617e246ccdbdd95002918fdb5c7d1774369698e4/azure_cli_ams-0.2.3-py2.py3-none-any.whl
# Collecting azure-cli-keyvault (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/db/28/4448d74df4d1915cf44df2eebffc3ef9483fede1f2ef645f53fb94bb7b23/azure_cli_keyvault-2.2.2-py2.py3-none-any.whl
# Collecting azure-cli-role (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/a1/66/570754583ca961c0edeb67b887a3bea5b4aea8732d53b602087d630673fe/azure_cli_role-2.1.4-py2.py3-none-any.whl
# Collecting azure-cli-interactive (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/db/69/2971cfad02d2daabe8de71645e5afcd850048c0f0441901888d6a62e411e/azure_cli_interactive-0.3.28-py2.py3-none-any.whl
# Collecting azure-cli-container (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/c1/7d/063e154e9f3d224237b897bdee94ad126ec29632522b6a12a6c58a126a3e/azure_cli_container-0.3.3-py2.py3-none-any.whl
# Collecting azure-cli-batch (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/6a/99/429a448e701583996d5e97d1b83640327a365368f7c3fe02f1399dd07ada/azure_cli_batch-3.3.3-py2.py3-none-any.whl
# Collecting azure-cli-batchai (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/db/b3/bf17b57506ede9630f8c0004eba5379dec8b04bbedeb6a9fe7a6ad7490d2/azure_cli_batchai-0.4.2-py2.py3-none-any.whl
# Collecting azure-cli-cognitiveservices (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d9/75/60d766cad8b91a7090c571cdd4d183e01c35b4299de2525a02e912419ba2/azure_cli_cognitiveservices-0.2.1-py2.py3-none-any.whl
# Collecting azure-cli-advisor (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/5f/9f/55b345c3f8fe5fffc1bb34d08c6fc1def81e7a16c01761e6fe5e77dd742c/azure_cli_advisor-0.6.0-py2.py3-none-any.whl
# Collecting azure-cli-lab (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/5a/20/65766a2b2a033453ae4fd9ac6ac0b02a9fd94a4ace948aad1c3643abc7d1/azure_cli_lab-0.1.1-py2.py3-none-any.whl
# Collecting azure-cli-dla (from azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/18/3a/5172215ec9228edfdaf0990ccb512a0cc1e1a5a34dd1cc873515257c5ef3/azure_cli_dla-0.2.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.9.1 in /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib/python3.6/site-packages (from keras==2.2.0->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12)) (1.15.1)
# Collecting keras-preprocessing==1.0.1 (from keras==2.2.0->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# Collecting keras-applications==1.0.2 (from keras==2.2.0->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl (43kB)
# Collecting scipy>=0.14 (from keras==2.2.0->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
# Collecting h5py (from keras==2.2.0->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/8e/cb/726134109e7bd71d98d1fcc717ffe051767aac42ede0e7326fd1787e5d64/h5py-2.8.0-cp36-cp36m-manylinux1_x86_64.whl (2.8MB)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/7b/18/03872177864b7ce4aa0302eae5726e8cb66dbb4f30a3408ed27a6639407f/azure_storage_common-1.3.0-py2.py3-none-any.whl (48kB)
# Collecting msrestazure>=0.4.33 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a4/48/cfa54772365b4d0b8f3e7af16354db768b0317b3273265b37c14f71b705b/msrestazure-0.5.0-py2.py3-none-any.whl
# Collecting pathspec (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/46/ff/23dca7dfac363b185314553c67f0c113b8981137a59861eb66ed77716d6a/pathspec-0.5.7.tar.gz
# Collecting docker (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/06/0b/ce97eb31058eddaef316973b8299b737ebab0bcb5798fd5a3225d53b4455/docker-3.5.0-py2.py3-none-any.whl (125kB)
# Collecting python-dateutil>=2.7.3 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/cf/f5/af2b09c957ace60dcfac112b669c45c8c97e32f94aa8b56da4c6d1682825/python_dateutil-2.7.3-py2.py3-none-any.whl (211kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting cryptography (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/59/32/92cade62c645756a83598edf56289e9b19aae5370642a7ce690cd06bc72f/cryptography-2.3.1-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
# Collecting SecretStorage<3.0.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting pytz (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/30/4e/27c34b62430286c6d59177a0842ed90dc789ce5d1ed740887653b898779a/pytz-2018.5-py2.py3-none-any.whl (510kB)
# Collecting contextlib2 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/91/66/6636001c0b6be5423f4bbaffe5febbf9eda39bd1941eb39a73504d8f6f71/azure_common-1.1.14-py2.py3-none-any.whl
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/b1/e9/0a11f4feefb9c4c2f7e30d4d448e15b32df3adabe370be70aaf4278fbb52/azure_storage_nspkg-3.0.0-py2.py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/67/5b/15e6a8109af53e4c2228142ea816532036700757d035fc1b9cd0f6a63b02/azure_mgmt_storage-2.0.0-py2.py3-none-any.whl (558kB)
# Collecting urllib3>=1.23 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/2b/26/c0cb69dfac2e5b7125db034045b8bcf937cf1e8d3df2009a87c33d0959f5/azure_mgmt_resource-2.0.0-py2.py3-none-any.whl (698kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/6f/17/55b974603c16be89c7a7c16bac57b7bce48527bf1bebc3f116f7215176e6/azure_mgmt_authorization-0.50.0-py2.py3-none-any.whl (81kB)
# Collecting msrest>=0.5.1 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/ad/2a/37b2481fa1a7cd727c07d20cbcb0a3f9bf9dd994930f44dd9770df15c28d/msrest-0.5.5-py2.py3-none-any.whl (47kB)
# Collecting backports.tempfile (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting jsonpickle (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/32/d5/2f47f03d3f64c31b0d7070b488274631d7567c36e81a9f744e6638bb0f0d/jsonpickle-0.9.6.tar.gz (67kB)
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/5e/50/cc68d1055456c40a873524b01e1bd24172b88dc6ceb905dadbabe0d3c058/azure_mgmt_containerregistry-2.1.0-py2.py3-none-any.whl (293kB)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/89/0a/29f7e2914033e2536026b8f0d7f8deb1edda68c9a93ce4757b2b1e39568b/azure_graphrbac-0.40.0-py2.py3-none-any.whl (63kB)
# Collecting ndg-httpsclient (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==0.1.4->azureml-defaults->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/dd/26/45de0cb737aeeeb2fa56cf12ab0042ba64dafd24bcc50bf8c8cdf913a1a6/azure_storage_blob-1.3.1-py2.py3-none-any.whl (77kB)
# Collecting traitlets (from jupyter-client->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl (74kB)
# Collecting pyzmq>=13 (from jupyter-client->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/48/93/59592cb294761aaa40589b544eaa5175446d687ff95beeeb666de60f3274/pyzmq-17.1.2-cp36-cp36m-manylinux1_x86_64.whl (998kB)
# Collecting jupyter-core (from jupyter-client->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl (126kB)
# Requirement already satisfied: tornado>=4.1 in /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib/python3.6/site-packages (from jupyter-client->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4)) (4.5.3)
# Collecting textwrap3 (from ansiwrap->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/e8/78/3bb4b819ae7ab81ba0759788b28671d7ae13186544c333f973e6c91a6726/textwrap3-0.9.1-py2.py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting s3transfer<0.2.0,>=0.1.10 (from boto3->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
# Collecting botocore<1.12.0,>=1.11.6 (from boto3->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/52/86/73e2825c9f452f6ea7ebbd715aa4621eb1f5d5e51e37cd2019437535909c/botocore-1.11.6-py2.py3-none-any.whl (4.6MB)
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/77/de/47e35a97b2b05c2fadbec67d44cfcdcd09b8086951b331d82de90d2912da/jsonschema-2.6.0-py2.py3-none-any.whl
# Collecting ipython-genutils (from nbformat->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting bleach (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/94/aa/0f7ce53f8688bb9f80c0cffacc3964ddfe08321c509c0bfe5062848951f9/bleach-2.1.4-py2.py3-none-any.whl
# Collecting pygments (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/02/ee/b6e02dc6529e82b75bb06823ff7d005b141037cb1416b10c6f00fc419dca/Pygments-2.2.0-py2.py3-none-any.whl (841kB)
# Collecting entrypoints>=0.2.2 (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/cc/8b/4eefa9b47f1910b3d2081da67726b066e379b04ca897acfe9f92bac56147/entrypoints-0.2.3-py2.py3-none-any.whl
# Collecting testpath (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/15/19/d7bc380c479a184e4a5a9ce516e4e2a773165f89b445f7cdced83d94de25/testpath-0.3.1-py2.py3-none-any.whl (161kB)
# Collecting mistune>=0.7.4 (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/c8/8c/87f4d359438ba0321a2ae91936030110bfcc62fef752656321a72b8c1af9/mistune-0.8.3-py2.py3-none-any.whl
# Collecting jinja2 (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl (126kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting idna<2.8,>=2.5 (from requests->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib/python3.6/site-packages (from requests->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4)) (2018.8.24)
# Collecting jedi>=0.10 (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/3d/68/8bbf0ef969095a13ba0d4c77c1945bd86e9811960d052510551d29a2f23b/jedi-0.12.1-py2.py3-none-any.whl (174kB)
# Collecting decorator (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/bc/bb/a24838832ba35baf52f32ab1a49b906b5f82fb7c76b2f6a7e35e140bac30/decorator-4.3.0-py2.py3-none-any.whl
# Collecting prompt-toolkit<2.0.0,>=1.0.15 (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/04/d1/c6616dd03701e7e2073f06d5c3b41b012256e42b72561f16a7bd86dd7b43/prompt_toolkit-1.0.15-py3-none-any.whl (247kB)
# Requirement already satisfied: setuptools>=18.5 in /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib/python3.6/site-packages (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4)) (40.2.0)
# Collecting simplegeneric>0.8 (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/3d/57/4d9c9e3ae9a255cd4e1106bb57e24056d3d0709fc01b2e3e345898e49d5b/simplegeneric-0.8.1.zip
# Collecting pexpect; sys_platform != "win32" (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/89/e6/b5a1de8b0cc4e07ca1b305a4fcc3f9806025c1b651ea302646341222f88b/pexpect-4.6.0-py2.py3-none-any.whl (57kB)
# Collecting backcall (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting pickleshare (from ipython>=5.0->papermill==0.14.1->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/9f/17/daa142fc9be6b76f26f24eeeb9a138940671490b91cb5587393f297c8317/pickleshare-0.7.4-py2.py3-none-any.whl
# Collecting azure-mgmt-redis==5.0.0 (from azure-cli-redis->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/90/a7/42342a984b2916972c5c5e24df94e3cd5e4377a8dc465a83415706d9be6f/azure_mgmt_redis-5.0.0-py2.py3-none-any.whl (43kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-redis->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting azure-mgmt-cdn==3.0.0 (from azure-cli-cdn->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ab/17/1684f274bd57ff81b0ac9000030d5796bf88c9735a093ba8b693c39ca6fd/azure_mgmt_cdn-3.0.0-py2.py3-none-any.whl (108kB)
# Collecting azure-mgmt-consumption==2.0.0 (from azure-cli-consumption->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/11/f4/2db9557494dfb17ff3edeae5726981143a7baace17df3712b189e343bd8c/azure_mgmt_consumption-2.0.0-py2.py3-none-any.whl (46kB)
# Collecting azure-mgmt-eventgrid==0.4.0 (from azure-cli-eventgrid->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/51/11/6828014c391b0c641ca94813b5c78cbf0984547252a7d71166594e074330/azure_mgmt_eventgrid-0.4.0-py2.py3-none-any.whl
# Collecting azure-mgmt-monitor==0.5.2 (from azure-cli-monitor->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/6a/3b/a8b95ee25f1c209ad82ad06de39f4efbfb9dc8a8dc5da5a7a48d7897bf3e/azure_mgmt_monitor-0.5.2-py2.py3-none-any.whl (247kB)
# Collecting azure-mgmt-eventhub==2.1.0 (from azure-cli-eventhubs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/b1/fa/2ae716793f2acdaf1f63029f774089f60e5cbbf3555b1077d2fc649e62d0/azure_mgmt_eventhub-2.1.0-py2.py3-none-any.whl (67kB)
# Collecting whoosh (from azure-cli-find->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ba/19/24d0f1f454a2c1eb689ca28d2f178db81e5024f42d82729a4ff6771155cf/Whoosh-2.7.4-py2.py3-none-any.whl (468kB)
# Collecting azure-multiapi-storage==0.2.2 (from azure-cli-storage->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/87/44/b723204921e29e3e67ca6d016f4e3fbb7d81f0a1dbb484685efa3b141f99/azure_multiapi_storage-0.2.2-py2.py3-none-any.whl (886kB)
# Collecting mock (from azure-cli-network->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/e6/35/f187bdf23be87092bd0f1200d43d23076cee4d0dec109f195173fd3ebc79/mock-2.0.0-py2.py3-none-any.whl (56kB)
# Collecting azure-mgmt-network==2.0.0rc3 (from azure-cli-network->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/43/8b/60054f2ecc12532f718f9d7214313318d19d0157de60691306b5e5af9549/azure_mgmt_network-2.0.0rc3-py2.py3-none-any.whl (5.0MB)
# Collecting azure-mgmt-trafficmanager==0.50.0 (from azure-cli-network->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ed/4f/c322d72dc92dde543471bc23f9ac0eb6b9d0dc2441bb5ce938250040e307/azure_mgmt_trafficmanager-0.50.0-py2.py3-none-any.whl (52kB)
# Collecting azure-mgmt-dns==2.0.0rc2 (from azure-cli-network->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/9d/12/1539094e9c1ae4d21acedfbf6eef4037265d12e40472a471d06a3a0eaa8b/azure_mgmt_dns-2.0.0rc2-py2.py3-none-any.whl (79kB)
# Collecting azure-mgmt-servicebus==0.5.1 (from azure-cli-servicebus->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/bf/c4/fcfa89812022b4b2ab308fa56ea0fcff6748808b11a77d81351700949122/azure_mgmt_servicebus-0.5.1-py2.py3-none-any.whl (111kB)
# Collecting pyOpenSSL (from azure-cli-iot->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
# Collecting azure-mgmt-iothubprovisioningservices==0.2.0 (from azure-cli-iot->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/84/ce/3500c731a5c5b31028e662aa41bc45f75301834a0c03adeacfe7ef7bd86e/azure_mgmt_iothubprovisioningservices-0.2.0-py2.py3-none-any.whl (60kB)
# Collecting azure-mgmt-iothub==0.5.0 (from azure-cli-iot->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/19/d6/b422df467b3d7f4e2975b590fbf6e12aaae0a497c7d080b4955a6a6d794a/azure_mgmt_iothub-0.5.0-py2.py3-none-any.whl (102kB)
# Collecting sshtunnel (from azure-cli-acs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/bf/8d/385c7e7c90e17934b3102ad2902e224c27a7173a6a57ef4805dcef8043b1/sshtunnel-0.1.4.tar.gz (48kB)
# Collecting paramiko>=2.0.8 (from azure-cli-acs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/3e/db/cb7b6656e0e7387637ce850689084dc0b94b44df31cc52e5fc5c2c4fd2c1/paramiko-2.4.1-py2.py3-none-any.whl (194kB)
# Collecting azure-mgmt-compute==4.0.0 (from azure-cli-acs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ff/32/cf501356a6f7ac0299141e7f7736cdf5cba60a5a72e030ab036e43b9aed4/azure_mgmt_compute-4.0.0-py2.py3-none-any.whl (2.1MB)
# Collecting scp (from azure-cli-acs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/ef/8c/399c5ddffc8c1bd2593ee6c8937ed31f005dcfa0c591da149f7b4b993f14/scp-0.11.0-py2.py3-none-any.whl
# Collecting azure-mgmt-containerservice==4.2.2 (from azure-cli-acs->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/19/2f/7ca5cc006337d8c9e80d608b1488ded6b525a92f6c9d787c9c807ba5a226/azure_mgmt_containerservice-4.2.2-py2.py3-none-any.whl (84kB)
# Collecting azure-mgmt-billing==0.2.0 (from azure-cli-billing->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/0f/24/5106287ea0f6562d965afb055e3c6c0da058f7844a70464e67bab56c6c4b/azure_mgmt_billing-0.2.0-py2.py3-none-any.whl
# Collecting azure-mgmt-datamigration==0.1.0 (from azure-cli-dms->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/a6/68/aba86e698f24f25f70d9ee2b15a2ca0d71b822932ace8ba96e5beb12efdd/azure_mgmt_datamigration-0.1.0-py2.py3-none-any.whl (219kB)
# Collecting azure-mgmt-rdbms==1.2.0 (from azure-cli-rdbms->azure-cli==2.0.41->-r /azureml-setup/condaenv.vlwcnv_i.requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/96/36/fae53c5584f38d96e716834f3213b8432ed19062c322dce9725be388dd24/azure_mgmt_rdbms-1.2.0-py2.py3-none-any.whl (159kB)
# ...
# Installing collected packages: applicationinsights, asn1crypto, pycparser, cffi, idna, cryptography, azure-nspkg, azure-common, python-dateutil, azure-storage-nspkg, urllib3, chardet, requests, azure-storage-common, PyJWT, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, pathspec, docker-pycreds, websocket-client, docker, azure-mgmt-nspkg, azure-mgmt-keyvault, SecretStorage, azure-mgmt-resource, argcomplete, azure-cli-nspkg, portalocker, azure-cli-telemetry, jmespath, colorama, pyyaml, antlr4-python3-runtime, pygments, tabulate, knack, wheel, pynacl, bcrypt, pyasn1, paramiko, pyOpenSSL, humanfriendly, azure-cli-core, azure-cli-command-modules-nspkg, azure-cli-profile, pytz, contextlib2, azure-mgmt-storage, ruamel.yaml, azure-mgmt-authorization, backports.weakref, backports.tempfile, jsonpickle, azure-mgmt-containerregistry, azure-graphrbac, ndg-httpsclient, azure-storage-blob, azureml-core, azureml-defaults, tqdm, decorator, ipython-genutils, traitlets, pyzmq, jupyter-core, jupyter-client, textwrap3, ansiwrap, docutils, botocore, s3transfer, boto3, pandas, click, jsonschema, nbformat, webencodings, html5lib, bleach, entrypoints, testpath, mistune, MarkupSafe, jinja2, pandocfilters, nbconvert, parso, jedi, wcwidth, prompt-toolkit, simplegeneric, ptyprocess, pexpect, backcall, pickleshare, ipython, future, papermill, python-dotenv, Pillow, wget, attrs, async-timeout, multidict, yarl, idna-ssl, aiohttp, toolz, azure-mgmt-redis, azure-cli-redis, azure-cli-cloud, azure-mgmt-cdn, azure-cli-cdn, azure-cli-feedback, azure-mgmt-consumption, azure-cli-consumption, azure-mgmt-eventgrid, azure-cli-eventgrid, azure-mgmt-monitor, azure-cli-monitor, azure-mgmt-eventhub, azure-cli-eventhubs, whoosh, azure-cli-find, azure-multiapi-storage, azure-cli-storage, pbr, mock, azure-mgmt-network, azure-mgmt-trafficmanager, azure-mgmt-dns, azure-cli-network, azure-mgmt-servicebus, azure-cli-servicebus, azure-cli-configure, azure-mgmt-iothubprovisioningservices, azure-mgmt-iothub, azure-cli-iot, azure-cli-acr, sshtunnel, azure-mgmt-compute, scp, azure-mgmt-containerservice, azure-cli-acs, azure-mgmt-billing, azure-cli-billing, azure-mgmt-datamigration, azure-cli-dms, azure-mgmt-rdbms, azure-cli-rdbms, azure-cli-extension, azure-keyvault, azure-mgmt-marketplaceordering, azure-mgmt-msi, azure-cli-vm, azure-mgmt-datalake-nspkg, azure-mgmt-datalake-store, azure-datalake-store, azure-cli-dls, azure-mgmt-cosmosdb, pydocumentdb, azure-cli-cosmosdb, azure-mgmt-web, vsts-cd-manager, xmltodict, azure-cli-appservice, azure-mgmt-recoveryservicesbackup, azure-mgmt-recoveryservices, azure-cli-backup, azure-mgmt-servicefabric, azure-cli-servicefabric, azure-mgmt-managementgroups, azure-cli-resource, azure-mgmt-sql, azure-cli-sql, azure-mgmt-reservations, azure-cli-reservations, azure-mgmt-media, azure-cli-ams, azure-cli-keyvault, azure-cli-role, azure-cli-interactive, azure-mgmt-loganalytics, azure-mgmt-containerinstance, azure-cli-container, azure-mgmt-batch, azure-batch, azure-cli-batch, azure-mgmt-batchai, azure-cli-batchai, azure-mgmt-cognitiveservices, azure-cli-cognitiveservices, azure-mgmt-advisor, azure-cli-advisor, azure-mgmt-devtestlabs, azure-cli-lab, azure-mgmt-datalake-analytics, azure-cli-dla, azure-cli, scipy, keras-preprocessing, h5py, keras-applications, keras
#   Found existing installation: wheel 0.31.1
#     Uninstalling wheel-0.31.1:
#       Successfully uninstalled wheel-0.31.1
# Successfully installed MarkupSafe-1.0 Pillow-5.2.0 PyJWT-1.6.4 SecretStorage-2.3.1 adal-1.0.2 aiohttp-3.3.2 ansiwrap-0.8.3 antlr4-python3-runtime-4.7.1 applicationinsights-0.11.6 argcomplete-1.9.4 asn1crypto-0.24.0 async-timeout-3.0.0 attrs-18.2.0 azure-batch-4.1.3 azure-cli-2.0.41 azure-cli-acr-2.1.4 azure-cli-acs-2.3.2 azure-cli-advisor-0.6.0 azure-cli-ams-0.2.3 azure-cli-appservice-0.2.3 azure-cli-backup-1.2.1 azure-cli-batch-3.3.3 azure-cli-batchai-0.4.2 azure-cli-billing-0.2.0 azure-cli-cdn-0.1.1 azure-cli-cloud-2.1.0 azure-cli-cognitiveservices-0.2.1 azure-cli-command-modules-nspkg-2.0.2 azure-cli-configure-2.0.18 azure-cli-consumption-0.4.0 azure-cli-container-0.3.3 azure-cli-core-2.0.45 azure-cli-cosmosdb-0.2.1 azure-cli-dla-0.2.2 azure-cli-dls-0.1.1 azure-cli-dms-0.1.0 azure-cli-eventgrid-0.2.0 azure-cli-eventhubs-0.2.3 azure-cli-extension-0.2.1 azure-cli-feedback-2.1.4 azure-cli-find-0.2.12 azure-cli-interactive-0.3.28 azure-cli-iot-0.3.1 azure-cli-keyvault-2.2.2 azure-cli-lab-0.1.1 azure-cli-monitor-0.2.3 azure-cli-network-2.2.4 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.1 azure-cli-rdbms-0.3.1 azure-cli-redis-0.3.2 azure-cli-reservations-0.3.2 azure-cli-resource-2.1.3 azure-cli-role-2.1.4 azure-cli-servicebus-0.2.2 azure-cli-servicefabric-0.1.2 azure-cli-sql-2.1.3 azure-cli-storage-2.2.1 azure-cli-telemetry-1.0.0 azure-cli-vm-2.2.2 azure-common-1.1.14 azure-datalake-store-0.0.27 azure-graphrbac-0.40.0 azure-keyvault-1.1.0 azure-mgmt-advisor-1.0.1 azure-mgmt-authorization-0.50.0 azure-mgmt-batch-5.0.1 azure-mgmt-batchai-2.0.0 azure-mgmt-billing-0.2.0 azure-mgmt-cdn-3.0.0 azure-mgmt-cognitiveservices-1.0.0 azure-mgmt-compute-4.0.0 azure-mgmt-consumption-2.0.0 azure-mgmt-containerinstance-1.0.0 azure-mgmt-containerregistry-2.1.0 azure-mgmt-containerservice-4.2.2 azure-mgmt-cosmosdb-0.4.0 azure-mgmt-datalake-analytics-0.2.0 azure-mgmt-datalake-nspkg-2.0.0 azure-mgmt-datalake-store-0.2.0 azure-mgmt-datamigration-0.1.0 azure-mgmt-devtestlabs-2.2.0 azure-mgmt-dns-2.0.0rc2 azure-mgmt-eventgrid-0.4.0 azure-mgmt-eventhub-2.1.0 azure-mgmt-iothub-0.5.0 azure-mgmt-iothubprovisioningservices-0.2.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-loganalytics-0.2.0 azure-mgmt-managementgroups-0.1.0 azure-mgmt-marketplaceordering-0.1.0 azure-mgmt-media-1.0.0rc1 azure-mgmt-monitor-0.5.2 azure-mgmt-msi-0.2.0 azure-mgmt-network-2.0.0rc3 azure-mgmt-nspkg-2.0.0 azure-mgmt-rdbms-1.2.0 azure-mgmt-recoveryservices-0.1.0 azure-mgmt-recoveryservicesbackup-0.1.1 azure-mgmt-redis-5.0.0 azure-mgmt-reservations-0.2.1 azure-mgmt-resource-2.0.0 azure-mgmt-servicebus-0.5.1 azure-mgmt-servicefabric-0.2.0 azure-mgmt-sql-0.9.1 azure-mgmt-storage-2.0.0 azure-mgmt-trafficmanager-0.50.0 azure-mgmt-web-0.35.0 azure-multiapi-storage-0.2.2 azure-nspkg-2.0.0 azure-storage-blob-1.3.1 azure-storage-common-1.3.0 azure-storage-nspkg-3.0.0 azureml-core-0.1.4 azureml-defaults-0.1.4 backcall-0.1.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.4 bleach-2.1.4 boto3-1.8.6 botocore-1.11.6 cffi-1.11.5 chardet-3.0.4 click-6.7 colorama-0.3.9 contextlib2-0.5.5 cryptography-2.3.1 decorator-4.3.0 docker-3.5.0 docker-pycreds-0.3.0 docutils-0.14 entrypoints-0.2.3 future-0.16.0 h5py-2.8.0 html5lib-1.0.1 humanfriendly-4.16.1 idna-2.7 idna-ssl-1.1.0 ipython-6.5.0 ipython-genutils-0.2.0 isodate-0.6.0 jedi-0.12.1 jinja2-2.10 jmespath-0.9.3 jsonpickle-0.9.6 jsonschema-2.6.0 jupyter-client-5.2.3 jupyter-core-4.4.0 keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1 knack-0.4.2 mistune-0.8.3 mock-2.0.0 msrest-0.5.5 msrestazure-0.5.0 multidict-4.4.0 nbconvert-5.3.1 nbformat-4.4.0 ndg-httpsclient-0.5.1 oauthlib-2.1.0 pandas-0.23.4 pandocfilters-1.4.2 papermill-0.14.1 paramiko-2.4.1 parso-0.3.1 pathspec-0.5.7 pbr-4.2.0 pexpect-4.6.0 pickleshare-0.7.4 portalocker-1.2.1 prompt-toolkit-1.0.15 ptyprocess-0.6.0 pyOpenSSL-18.0.0 pyasn1-0.4.4 pycparser-2.18 pydocumentdb-2.3.2 pygments-2.2.0 pynacl-1.2.1 python-dateutil-2.7.3 python-dotenv-0.9.0 pytz-2018.5 pyyaml-3.13 pyzmq-17. ...
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container a94c1a57bbb3
#  ---> b6f4cb5124cf
# Step 9/13 : ENV PATH /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/bin:$PATH
#  ---> Running in 807b5eff6219
# Removing intermediate container 807b5eff6219
#  ---> 4f71da692fd8
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/lib:$LD_LIBRARY_PATH
#  ---> Running in 40b61fe6ab59
# Removing intermediate container 40b61fe6ab59
#  ---> 63d89c32da49
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> d5fb2e1e7b79
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven,https://azuremldownloads.blob.core.windows.net/repo5qh91kdjs6" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12,com.microsoft:dprep_2.11:0.18.0,com.microsoft.sqlserver:mssql-jdbc:6.2.1.jre8" "--conf" "spark.app.name=Azure ML Experiment" "--conf" "spark.yarn.maxAppAttempts=1" "--driver-java-options" "-Dlog4j.configuration=file:./azureml-setup/log4j.properties" "--conf" "spark.eventLog.enabled=true" "--conf" "spark.eventLog.dir=./azureml-logs" /azureml-setup/spark_cache.py'; fi
#  ---> Running in 9051d6be1163
# Removing intermediate container 9051d6be1163
#  ---> 657b820a2741
# Step 13/13 : CMD ["bash"]
#  ---> Running in bf1edb7e213c
# Removing intermediate container bf1edb7e213c
#  ---> dfa55064e4d3
# Successfully built dfa55064e4d3
# Successfully tagged azureml/azureml_bce24304934b364a91b9452e2beac9e2:latest
#
#
# Logging experiment running status in history service.
# Running: ['sudo', 'docker', 'run', '--name', 'train-on-local_1536091959', '--rm', '-v', '/tmp/azureml_runs/train-on-local_1536091959:/azureml-run', '-e', 'AZUREML_DOCKERFILE_PATH=azureml-setup/Dockerfile', '-e', 'AZUREML_CONDA_ENVIRONMENT_EXISTENCE_INDICATOR=$HOME/.azureml/locks/azureml_a517395017fe17c5d21cc41933743a63', '-e', 'AZUREML_CONDA_ENVIRONMENT_PATH=/azureml-envs/azureml_a517395017fe17c5d21cc41933743a63', '-e', 'AZUREML_CONDA_LOCK_PATH=$HOME/.azureml/locks/azureml_conda_lock', '-e', 'AZUREML_USER_CONDA_DIRECTORY=$HOME/.azureml', '-e', 'EXAMPLE_ENV_VAR=EXAMPLE_VALUE', '-e', 'AZUREML_CONTEXT_MANAGER_OUTPUTCOLLECTION=null', '-e', 'AZUREML_CONTEXT_MANAGER_PROJECTPYTHONPATH=null', '-e', 'AZUREML_RUN_TOKEN_EXPIRY=1536696760', '-e', 'AZUREML_RUN_TOKEN=eyJhbGciOiJSUzI1NiIsImtpZCI6IjMwQTk2ODc3NzgyNDgwMEFFQTc3RTFGMzZBMzM0NTU4OUI0N0VDREIiLCJ0eXAiOiJKV1QifQ.....fnh5enCiJ_V-uTVTMUiHRGkmoa22BTC90y65WvPqVAfMbwJi-R0Fk8G7DeCMbV58efZXq1xiP-R_O9KdOadf_JsRj5KBGboxyAHHJShdcW686VCmDJfwBXB1NgPTLBB2CQUkivglnlKzjxnU8jn0IrTtdq1FT0gIl8BJFD4KQMNyI3hBIJSnxE9k2YHZw0cKHrlpVAsRKtiWMZbsIvjStQ9YG_OuEFsWHnEgiW2IHZpFQebnY8RW-EOqHt9zdnuiyrBSoaZH09EncAFSGekbwmazckGg1X35YtnsdJ0C6rpVXMGUisYHNqqXp965f2nPlvqgQ1meTUgQ1eT52LKSUg', '-e', 'PYTHONUNBUFFERED=True', '-e', 'AZUREML_ARM_PROJECT_NAME=train-on-local', '-e', 'AZUREML_ARM_WORKSPACE_NAME=jayavienna', '-e', 'AZUREML_ARM_SUBSCRIPTION=edf507a2-6235-46c5-b560-fd463ba2e771', '-e', 'AZUREML_ARM_RESOURCEGROUP=jayavienna', '-e', 'AZUREML_ARM_SCOPE=/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/jayavienna/providers/Microsoft.MachineLearningServices/workspaces/jayavienna/projects/train-on-local', '-e', 'AZUREML_DISCOVERY_SERVICE_ENDPOINT=https://eastus2.experiments.azureml.net/discovery', '-e', 'AZUREML_SERVICE_ENDPOINT=https://eastus2.experiments.azureml.net', '-e', 'AZUREML_RUN_CONFIGURATION=azureml-setup/mutated_run_configuration.json', '-e', 'AZUREML_INSTRUMENTATION_KEY=c684677d-b3a0-4709-a00e-78e5b31cfafa', '-e', 'AZUREML_DRIVERLOG_PATH=azureml-logs/driver_log.txt', '-e', 'AZUREML_CONTROLLOG_PATH=azureml-logs/control_log.txt', '-e', 'AZUREML_LOGDIRECTORY_PATH=azureml-logs/', '-e', 'AZUREML_PIDFILE_PATH=azureml-setup/pid.txt', '-e', 'AZUREML_RUN_ID=train-on-local_1536091959', 'azureml/azureml_bce24304934b364a91b9452e2beac9e2', '/bin/bash', '-c', 'cd /azureml-run && "/azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/bin/python" "azureml-setup/run_script.py" "/azureml-envs/azureml_a517395017fe17c5d21cc41933743a63/bin/python" "azureml-setup/context_manager_injector.py" "-i" "ProjectPythonPath:context_managers.ProjectPythonPath" "-i" "OutputCollection:context_managers.RunHistory" "train.py"']
# Uploading experiment status to history service.
# Adding run profile attachment azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# Using TensorFlow backend.
# 2018-09-04 20:17:49.744044: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-09-04 20:17:49.745212: I tensorflow/core/common_runtime/process_util.cc:69] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://github.com/adamcasson/resnet152/releases/download/v0.1/resnet152_weights_tf.h5
#
#      8192/243179624 [..............................] - ETA: 1:11
#    753664/243179624 [..............................] - ETA: 17s
#   2457600/243179624 [..............................] - ETA: 10s
#   6062080/243179624 [..............................] - ETA: 6s
#  12738560/243179624 [>.............................] - ETA: 3s
#  22478848/243179624 [=>............................] - ETA: 2s
#  31621120/243179624 [==>...........................] - ETA: 2s
#  40230912/243179624 [===>..........................] - ETA: 1s
#  51068928/243179624 [=====>........................] - ETA: 1s
#  61071360/243179624 [======>.......................] - ETA: 1s
#  64233472/243179624 [======>.......................] - ETA: 1s
#  73023488/243179624 [========>.....................] - ETA: 1s
#  80314368/243179624 [========>.....................] - ETA: 1s
#  85458944/243179624 [=========>....................] - ETA: 1s
#  90456064/243179624 [==========>...................] - ETA: 1s
#  95502336/243179624 [==========>...................] - ETA: 1s
# 100491264/243179624 [===========>..................] - ETA: 1s
# 105086976/243179624 [===========>..................] - ETA: 1s
# 108462080/243179624 [============>.................] - ETA: 1s
# 111624192/243179624 [============>.................] - ETA: 1s
# 122421248/243179624 [==============>...............] - ETA: 1s
# 126951424/243179624 [==============>...............] - ETA: 1s
# 134316032/243179624 [===============>..............] - ETA: 0s
# 139370496/243179624 [================>.............] - ETA: 0s
# 143966208/243179624 [================>.............] - ETA: 0s
# 149364736/243179624 [=================>............] - ETA: 0s
# 153010176/243179624 [=================>............] - ETA: 0s
# 159301632/243179624 [==================>...........] - ETA: 0s
# 164405248/243179624 [===================>..........] - ETA: 0s
# 169394176/243179624 [===================>..........] - ETA: 0s
# 174342144/243179624 [====================>.........] - ETA: 0s
# 178184192/243179624 [====================>.........] - ETA: 0s
# 186662912/243179624 [======================>.......] - ETA: 0s
# 192913408/243179624 [======================>.......] - ETA: 0s
# 197902336/243179624 [=======================>......] - ETA: 0s
# 202874880/243179624 [========================>.....] - ETA: 0s
# 207912960/243179624 [========================>.....] - ETA: 0s
# 212967424/243179624 [=========================>....] - ETA: 0s
# 217767936/243179624 [=========================>....] - ETA: 0s
# 222920704/243179624 [==========================>...] - ETA: 0s
# 228114432/243179624 [===========================>..] - ETA: 0s
# 233201664/243179624 [===========================>..] - ETA: 0s
# 236879872/243179624 [============================>.] - ETA: 0s
# 243187712/243179624 [==============================] - 2s 0us/step
# Downloading data from https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json
#
#  8192/35363 [=====>........................] - ETA: 0s
# 40960/35363 [==================================] - 0s 0us/step
# Predicted: [[('n02127052', 'lynx', 0.99591225), ('n02128385', 'leopard', 0.0011504501), ('n02123159', 'tiger_cat', 0.00094180217)]]
# The experiment completed successfully. Starting post-processing steps.
#
# Execution Summary
# =================
# RunId: train-on-local_1536091959
#
# CPU times: user 52.2 s, sys: 2.11 s, total: 54.3 s
# Wall time: 46min 19s
