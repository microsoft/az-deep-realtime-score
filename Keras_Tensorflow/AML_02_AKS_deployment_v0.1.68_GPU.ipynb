# %% [markdown]
# # Deploy a DL model to AKS GPU cluster
# This notebook shows the steps for deploying a pretrained deep learning model (ResNet 152 model on Imagenet dataset) on a GPU enabled Azure Kubernetes Service (AKS) cluster through [Azure Machine Learning](https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py).
#
# Before proceeding, please make sure you have taken care of these [prerequisite steps](../README.md).
#
# This tutorial will take you through the following steps:
#  * [Get Workspace](#get_workspace)
#  * [Persist Pretrained Model](#persist_model)
#  * [Register a Model](#register_model)
#  * [Create an Image](#create_image)
#  * [Provision a Cluster](#provision_cluster)
#  * [Deploy Web Service to Cluster](#deploy_ws)
#  * [Test Web Service](#test_ws)
#  * [Clean Up Resources](#clean_up)

# %%
from azureml.core import Workspace
from azureml.core.compute import AksCompute, ComputeTarget
from azureml.core.webservice import Webservice, AksWebservice
from azureml.core.image import Image
from azureml.core.model import Model

# %%
import azureml.core
print(azureml.core.VERSION)
# Out:
# 0.1.68

# %%
import os
curr_dir = os.getcwd()

# locations for deployment - change as necessary
temp_dir = os.path.join(curr_dir,'deployment')  
model_path = os.path.join(temp_dir,'model_resnet_weights.h5')
score_file_path = os.path.join(temp_dir, 'score.py')
test_image_path = os.path.join(temp_dir, '220px-Lynx_lynx_poing.jpg')


if not os.path.exists(temp_dir):
    os.makedirs(temp_dir)

# print(os.getcwd())
# print(os.listdir(os.getcwd()))

# %% [markdown]
# <a id='get_workspace'></a>
# ## Get workspace
# Load existing workspace from the config file info.

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Found the config file in: /workspace/AKSDeploymentTutorial_AML/Keras_Tensorflow/aml_config/config.json
# yanzamlworkspace
# yanzamlworkspace
# eastus2
# edf507a2-6235-46c5-b560-fd463ba2e771

# %% [markdown]
# <a id='persist_model'></a>
# ## Persist Pretrained Model

# %%
#Creating the model pickle file
import tensorflow as tf
from resnet152 import ResNet152
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input, decode_predictions

model = ResNet152(weights='imagenet')
# Out:
# Using TensorFlow backend.

# %%
model

# %%
model.save_weights(model_path)

# %%
model.load_weights(model_path)

# %%
model

# %% [markdown]
# <a id='regisger_model'></a>
# ## Register the model
# Register an existing trained model, add descirption and tags.

# %%
#Register the model
from azureml.core.model import Model
model = Model.register(model_path = model_path, # this points to a local file
                       model_name = "resnet_model", # this is the name the model is registered as
                       tags = {'model': "dl", 'framework': "resnet"},
                       description = "resnet 152 model",
                       workspace = ws)

print(model.name, model.description, model.version)
# Out:
# Registering model resnet_model
# resnet_model resnet 152 model 1

# %% [markdown]
# ## Test the scoring script at local host

# %%
#define init() function
def init():
    import tensorflow as tf
    from resnet152 import ResNet152
    from keras.preprocessing import image
    from keras.applications.imagenet_utils import preprocess_input, decode_predictions

    import numpy as np
    import timeit as t
    import base64
    import json
    from PIL import Image, ImageOps
    from io import BytesIO
    import logging

    global model
    model = ResNet152(weights='imagenet')
    print('Model loaded')

# %%
init()
# Out:
# Model loaded

# %%
#define run() function 
def run(inputString):
    
    import tensorflow as tf
    from resnet152 import ResNet152
    from keras.preprocessing import image
    from keras.applications.imagenet_utils import preprocess_input, decode_predictions

    import numpy as np
    import timeit as t
    import base64
    import json
    from PIL import Image, ImageOps
    from io import BytesIO
    import logging   
    
    model = ResNet152(weights='imagenet')
    print('Model loaded')
  
    
     
    responses = []
    base64Dict = json.loads(inputString)

    for k, v in base64Dict.items():
        img_file_name, base64Img = k, v
    decoded_img = base64.b64decode(base64Img)
    img_buffer = BytesIO(decoded_img)
    imageData = Image.open(img_buffer).convert("RGB")
    
    # Evaluate the model using the input data
    img = ImageOps.fit(imageData, (224,224), Image.ANTIALIAS)
    img = np.array(img) # shape: (224, 224, 3)
    
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    
    preds = model.predict(img)
    print('Predicted:', decode_predictions(preds, top=3))
    resp = {img_file_name: str(decode_predictions(preds, top=3))}

    responses.append(resp)
    return json.dumps(responses)

# %%
from io import BytesIO
from PIL import Image, ImageOps
import base64
import json

img_path = test_image_path
encoded = None
with open(img_path, 'rb') as file:
  encoded = base64.b64encode(file.read())
img_dict = {img_path: encoded.decode('utf-8')}
body = json.dumps(img_dict)
resp = run(body)
print(resp)
# Out:
# Model loaded
# Predicted: [[('n02127052', 'lynx', 0.9816487), ('n02128385', 'leopard', 0.007744099), ('n02123159', 'tiger_cat', 0.0036861112)]]
# [{"220px-Lynx_lynx_poing.jpg": "[[('n02127052', 'lynx', 0.9816487), ('n02128385', 'leopard', 0.007744099), ('n02123159', 'tiger_cat', 0.0036861112)]]"}]

# %% [markdown]
# ## Write and save scoring script

# %%
# %%writefile $score_file_path
# def init():
#     import tensorflow as tf
#     from resnet152 import ResNet152
#     from keras.preprocessing import image
#     from keras.applications.imagenet_utils import preprocess_input, decode_predictions
#
#     import numpy as np
#     import timeit as t
#     import base64
#     import json
#     from PIL import Image, ImageOps
#     from io import BytesIO
#     import logging
#
#     global model
#     model = ResNet152(weights='imagenet')
#     print('Model loaded')
#
# def run(inputString):
#
#     import tensorflow as tf
#     from resnet152 import ResNet152
#     from keras.preprocessing import image
#     from keras.applications.imagenet_utils import preprocess_input, decode_predictions
#
#     import numpy as np
#     import timeit as t
#     import base64
#     import json
#     from PIL import Image, ImageOps
#     from io import BytesIO
#     import logging
#
#     model = ResNet152(weights='imagenet')
#     print('Model loaded')
#
#     responses = []
#     base64Dict = json.loads(inputString)
#
#     for k, v in base64Dict.items():
#         img_file_name, base64Img = k, v
#     decoded_img = base64.b64decode(base64Img)
#     img_buffer = BytesIO(decoded_img)
#     imageData = Image.open(img_buffer).convert("RGB")
#
#     # Evaluate the model using the input data
#     img = ImageOps.fit(imageData, (224,224), Image.ANTIALIAS)
#     img = np.array(img) # shape: (224, 224, 3)
#
#     img = np.expand_dims(img, axis=0)
#     img = preprocess_input(img)
#
#     preds = model.predict(img)
#     print('Predicted:', decode_predictions(preds, top=3))
#     resp = {img_file_name: str(decode_predictions(preds, top=3))}
#
#     responses.append(resp)
#     return json.dumps(responses)
# Out:
# Writing /workspace/AKSDeploymentTutorial_AML/Keras_Tensorflow/temp/score.py

# %% [markdown]
# <a id='create_image'></a>
# ## Create an Image
# Create an image using the registered model the script that will load and run the model.

# %%
from azureml.core.image import ContainerImage

image_config = ContainerImage.image_configuration(execution_script = "score.py",
                                                  runtime = "python",
                                                  conda_file = "myenv_yz.yml",
                                                  docker_file = "mydockerfile",
                                                  description = "Image for AKS Deployment Tutorial",
                                                  tags = {"name":"AKS","project":"AML"}, 
                                                  dependencies = ["resnet152.py"],
                                                  enable_gpu = True
                                                 )

image = ContainerImage.create(name = "myimage15",
                              # this is the model object
                              models = [],                              
                              image_config = image_config,
                              workspace = ws)

image.wait_for_creation(show_output = True)
# Out:
# Creating image
# Running................................................................................................................................................................................................................
# SucceededImage creation operation finished for image myimage15:1, operation "Succeeded"

# %% [markdown]
# <a id='provision_cluster'></a>
# ## Provision the AKS Cluster¶
# This is a one time setup. You can reuse this cluster for multiple deployments after it has been created. If you delete the cluster or the resource group that contains it, then you would have to recreate it.

# %%
resource_group = 'yanzamlworkspace'
aks_name = 'yanz-aksgpu-v10'

# %%
# !az aks create --resource-group $resource_group --name $aks_name --node-count 1 --generate-ssh-keys -k "1.10.8" -s Standard_NC6
# Out:
# SSH key files '/root/.ssh/id_rsa' and '/root/.ssh/id_rsa.pub' have been generated under ~/.ssh to allow SSH access to the VM. If using machines without permanent storage like Azure Cloud Shell without an attached file share, back up your keys to a safe location
#  - Interrupted ..ncipal creation[##################################]  100.0000%Deployment failed. Correlation ID: e7f2baa2-ccd2-4451-92f6-49b89f9e6a81. Provisioning of resource(s) for container service yanz-aksgpu-v10 in resource group yanzamlworkspace failed. Message: Operation results in exceeding quota limits of Core. Maximum allowed: 48, Current in use: 48, Additional requested: 6. Please read more about quota increase at http://aka.ms/corequotaincrease.. Details:

# %%
#Provision AKS cluster with GPU machine
# Use the default configuration (can also provide parameters to customize)
prov_config = AksCompute.provisioning_configuration(vm_size='Standard_NC6')

aks_name = 'yanz-aks-1' 
# Create the cluster
aks_target = ComputeTarget.create(workspace = ws, 
                                  name = aks_name, 
                                  provisioning_configuration = prov_config)

# %% [markdown]
# ## Optional step: Attach existing AKS cluster¶

# %%
'''
# Attach an existing AKS cluster
# Use the default configuration (can also provide parameters to customize)
resource_id = '/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourcegroups/yanzamlworkspace/providers/Microsoft.ContainerService/managedClusters/yanz-aks-1c6750233554'

create_name='my-gpu-aks' 
# Create the cluster
aks_target = AksCompute.attach(workspace=ws, name=create_name, resource_id=resource_id)
# Wait for the operation to complete
aks_target.wait_for_completion(True)

'''
# Out:
# Creating.
# SucceededProvisioning operation finished, operation "Succeeded"

# %%
aks_target

# %%
#list images
images = ws.images()
images
# Out:
# {'myimage1': ContainerImage(workspace=<azureml.core.workspace.Workspace object at 0x7ff75fb7fd68>, name=myimage1, id=myimage1:1, tags={'name': 'AKS', 'project': 'AML'}, properties={}, version=1)}

# %%
#for img in ws.images():
#    if img.name == 'myimage1': img.delete()

# %%
# %%time
aks_target.wait_for_completion(show_output = True)
print(aks_target.provisioning_state)
print(aks_target.provisioning_errors)
# Out:
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# None
# CPU times: user 26 ms, sys: 7.33 ms, total: 33.3 ms
# Wall time: 463 ms

# %%
# !az aks get-credentials -n 'yanz-aks-cpu1549812594' -g yanzamlworkspace -a -f config_cpuaks
# Out:
# Merged "yanz-aks-cpu1549812594-admin" as current context in config_cpuaks

# %%
# !kubectl --kubeconfig config get services
# Out:
# /bin/sh: 1: kubectl: not found

# %% [markdown]
# <a id='deploy_ws'></a>
# ## Deploy web service to AKS¶

# %%
'''
#Deploy web service to AKS
#Set the web service configuration (using default here)
aks_config = AksWebservice.deploy_configuration()
print(aks_config)
'''
# Out:
# <azureml.core.webservice.aks.AksServiceDeploymentConfiguration object at 0x7fa51aabca20>

# %%
#Deploy web service to AKS
#Set the web service configuration (using customized configuration)
aks_config = AksWebservice.deploy_configuration(memory_gb=2.0, enable_app_insights=True)
print(aks_config)
# Out:
# <azureml.core.webservice.aks.AksServiceDeploymentConfiguration object at 0x7f89524dbcf8>

# %%
# by default the 500MB -- memory_gb; up to 1.4 GB  - manually - profiling ;  cluster capacity is 24G
help(AksWebservice)
# Out:
# Help on class AksWebservice in module azureml.core.webservice.aks:
#
# class AksWebservice(azureml.core.webservice.webservice.Webservice)
#  |  Class for AzureML AKS Webservices
#  |
#  |  Method resolution order:
#  |      AksWebservice
#  |      azureml.core.webservice.webservice.Webservice
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  add_properties(self, properties)
#  |      Add key value pairs to this Webservice's properties dictionary.
#  |
#  |      :param properties: The dictionary of properties to add
#  |      :type properties: dict[str, str]
#  |
#  |  add_tags(self, tags)
#  |      Add key value pairs to this Webservice's tags dictionary
#  |
#  |      :param tags: The dictionary of tags to add
#  |      :type tags: dict[str, str]
#  |      :raises: WebserviceException
#  |
#  |  remove_tags(self, tags)
#  |      Remove the specified keys from this Webservice's dictionary of tags.
#  |
#  |      :param tags: The list of keys to remove
#  |      :type tags: list[str]
#  |
#  |  run(self, input_data)
#  |      Call this Webservice with the provided input
#  |
#  |      :param input_data: The input to call the Webservice with
#  |      :type input_data: varies
#  |      :return: The result of calling the Webservice
#  |      :rtype: dict
#  |      :raises: WebserviceException
#  |
#  |  serialize(self)
#  |      Convert this Webservice into a json serialized dictionary.
#  |
#  |      :return: The json representation of this Webservice
#  |      :rtype: dict
#  |
#  |  update(self, image=None, autoscale_enabled=None, autoscale_min_replicas=None, autoscale_max_replicas=None, autoscale_refresh_seconds=None, autoscale_target_utilization=None, collect_model_data=None, auth_enabled=None, cpu_cores=None, memory_gb=None, enable_app_insights=None, scoring_timeout_ms=None, replica_max_concurrent_requests=None, num_replicas=None, tags=None, properties=None, description=None)
#  |      Update the Webservice with provided properties. Values left as None will remain unchanged in this Webservice
#  |
#  |      :param image: A new Image to deploy to the Webservice
#  |      :type image: Image
#  |      :param autoscale_enabled: Enable or disable autoscaling of this Webservice
#  |      :type autoscale_enabled: bool
#  |      :param autoscale_min_replicas: The minimum number of containers to use when autoscaling this Webservice
#  |      :type autoscale_min_replicas: int
#  |      :param autoscale_max_replicas: The maximum number of containers to use when autoscaling this Webservice
#  |      :type autoscale_max_replicas: int
#  |      :param autoscale_refresh_seconds: How often the autoscaler should attempt to scale this Webservice
#  |      :type autoscale_refresh_seconds: int
#  |      :param autoscale_target_utilization: The target utilization (in percent out of 100) the autoscaler should
#  |          attempt to maintain for this Webservice
#  |      :type autoscale_target_utilization: int
#  |      :param collect_model_data: Enable or disable model data collection for this Webservice
#  |      :type collect_model_data: bool
#  |      :param auth_enabled: Whether or not to enable auth for this Webservice
#  |      :type auth_enabled: bool
#  |      :param cpu_cores: The number of cpu cores to allocate for this Webservice. Can be a decimal
#  |      :type cpu_cores: float
#  |      :param memory_gb: The amount of memory (in GB) to allocate for this Webservice. Can be a decimal
#  |      :type memory_gb: float
#  |      :param enable_app_insights: Whether or not to enable Application Insights logging for this Webservice
#  |      :type enable_app_insights: bool
#  |      :param scoring_timeout_ms: A timeout to enforce for scoring calls to this Webservice
#  |      :type scoring_timeout_ms: int
#  |      :param replica_max_concurrent_requests: The number of maximum concurrent requests per node to allow for this
#  |          Webservice
#  |      :type replica_max_concurrent_requests: int
#  |      :param num_replicas: The number of containers to allocate for this Webservice
#  |      :type num_replicas: int
#  |      :param tags: Dictionary of key value tags to give this Webservice. Will replace existing tags.
#  |      :type tags: dict[str, str]
#  |      :param properties: Dictionary of key value properties to add to existing properties dictionary
#  |      :type properties: dict[str, str]
#  |      :param description: A description to give this Webservice
#  |      :type description: str
#  |      :raises: WebserviceException
#  |
#  |  update_deployment_state(self)
#  |      Perform an in-place update of the properties of the object based on the current state of the
#  |      corresponding cloud object. Primarily useful for manual polling of deployment state.
#  |
#  |  wait_for_deployment(self, show_output=False)
#  |      Automatically poll on the running Webservice deployment.
#  |
#  |      :param show_output: Option to print more verbose output
#  |      :type show_output: bool
#  |      :raises: WebserviceException
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  deploy_configuration(autoscale_enabled=None, autoscale_min_replicas=None, autoscale_max_replicas=None, autoscale_refresh_seconds=None, autoscale_target_utilization=None, collect_model_data=None, auth_enabled=None, cpu_cores=None, memory_gb=None, enable_app_insights=None, scoring_timeout_ms=None, replica_max_concurrent_requests=None, num_replicas=None, primary_key=None, secondary_key=None, tags=None, properties=None, description=None)
#  |      Create a configuration object for deploying to an AKS compute target
#  |
#  |      :param autoscale_enabled: Whether or not to enable autoscaling for this Webservice
#  |      :type autoscale_enabled: bool
#  |      :param autoscale_min_replicas: The minimum number of containers to use when autoscaling this Webservice
#  |      :type autoscale_min_replicas: int
#  |      :param autoscale_max_replicas: The maximum number of containers to use when autoscaling this Webservice
#  |      :type autoscale_max_replicas: int
#  |      :param autoscale_refresh_seconds: How often the autoscaler should attempt to scale this Webservice
#  |      :type autoscale_refresh_seconds: int
#  |      :param autoscale_target_utilization: The target utilization (in percent out of 100) the autoscaler should
#  |          attempt to maintain for this Webservice
#  |      :type autoscale_target_utilization: int
#  |      :param collect_model_data: Whether or not to enable model data collection for this Webservice
#  |      :type collect_model_data: bool
#  |      :param auth_enabled: Whether or not to enable auth for this Webservice
#  |      :type auth_enabled: bool
#  |      :param cpu_cores: The number of cpu cores to allocate for this Webservice. Can be a decimal
#  |      :type cpu_cores: float
#  |      :param memory_gb: The amount of memory (in GB) to allocate for this Webservice. Can be a decimal
#  |      :type memory_gb: float
#  |      :param enable_app_insights: Whether or not to enable Application Insights logging for this Webservice
#  |      :type enable_app_insights: bool
#  |      :param scoring_timeout_ms: A timeout to enforce for scoring calls to this Webservice
#  |      :type scoring_timeout_ms: int
#  |      :param replica_max_concurrent_requests: The number of maximum concurrent requests per node to allow for this
#  |          Webservice
#  |      :type replica_max_concurrent_requests: int
#  |      :param num_replicas: The number of containers to allocate for this Webservice
#  |      :type num_replicas: int
#  |      :param primary_key: A primary auth key to use for this Webservice
#  |      :type primary_key: str
#  |      :param secondary_key: A secondary auth key to use for this Webservice
#  |      :type secondary_key: str
#  |      :param tags: Dictionary of key value tags to give this Webservice
#  |      :type tags: dict[str, str]
#  |      :param properties: Dictionary of key value properties to give this Webservice. These properties cannot
#  |          be changed after deployment, however new key value pairs can be added
#  |      :type properties: dict[str, str]
#  |      :param description: A description to give this Webservice
#  |      :type description: str
#  |      :return: A configuration object to use when deploying a Webservice object
#  |      :rtype: AksServiceDeploymentConfiguration
#  |      :raises: WebserviceException
#  |
#  |  deserialize(workspace, webservice_payload)
#  |      Convert a json object into a AksWebservice object. Will fail if the provided workspace is not the workspace the
#  |      Webservice is registered under.
#  |
#  |      :param workspace: The workspace object the AksWebservice is registered under
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param webservice_payload: A json object to convert to a Webservice object
#  |      :type webservice_payload: dict
#  |      :return: The AksWebservice representation of the provided json object
#  |      :rtype: AksWebservice
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from azureml.core.webservice.webservice.Webservice:
#  |
#  |  __init__(self, workspace, name)
#  |      Webservice constructor is used to retrieve a cloud representation of a Webservice object associated with the
#  |      provided workspace. Will return an instance of a child class corresponding to the specific type of the
#  |      retrieved Webservice object.
#  |
#  |      :param workspace: The workspace object containing the Webservice object to retrieve
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param name: The name of the of the Webservice object to retrieve
#  |      :type name: str
#  |      :return: An instance of a child of Webservice corresponding to the specific type of the retrieved
#  |          Webservice object
#  |      :rtype: Webservice
#  |      :raises: WebserviceException
#  |
#  |  delete(self)
#  |      Delete this Webservice from its associated workspace
#  |
#  |      :raises: WebserviceException
#  |
#  |  get_keys(self)
#  |      Retrieve auth keys for this Webservice
#  |
#  |      :return: The auth keys for this Webservice
#  |      :rtype: (str, str)
#  |      :raises: WebserviceException
#  |
#  |  get_logs(self, num_lines=5000)
#  |      Retrieve logs for this Webservice.
#  |
#  |      :param num_lines: The maximum number of log lines to retrieve
#  |      :type num_lines: int
#  |      :return: The logs for this Webservice
#  |      :rtype: str
#  |      :raises: WebserviceException
#  |
#  |  regen_key(self, key)
#  |      Regenerate one of the Webservice's keys. Must specify either 'Primary' or 'Secondary' key.
#  |
#  |      :param key: Which key to regenerate. Options are 'Primary' or 'Secondary'
#  |      :type key: str
#  |      :raises: WebserviceException
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from azureml.core.webservice.webservice.Webservice:
#  |
#  |  __new__(cls, workspace, name)
#  |      Webservice constructor is used to retrieve a cloud representation of a Webservice object associated with the
#  |      provided workspace. Will return an instance of a child class corresponding to the specific type of the
#  |      retrieved Webservice object.
#  |
#  |      :param workspace: The workspace object containing the Webservice object to retrieve
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param name: The name of the of the Webservice object to retrieve
#  |      :type name: str
#  |      :return: An instance of a child of Webservice corresponding to the specific type of the retrieved
#  |          Webservice object
#  |      :rtype: Webservice
#  |      :raises: WebserviceException
#  |
#  |  deploy(workspace, name, model_paths, image_config, deployment_config=None, deployment_target=None)
#  |      Deploy a Webservice from zero or more model files. This will register any models files provided and create an
#  |      image in the process, all associated with the specified Workspace.
#  |
#  |      :param workspace: A Workspace object to associate the Webservice with
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param name: The name to give the deployed workspace. Must be unique to the workspace.
#  |      :type name: str
#  |      :param model_paths: A list of on disk paths to model files or folder. Can be an empty list.
#  |      :type model_paths: list[str]
#  |      :param image_config: An ImageConfig object used to determine required Image properties.
#  |      :type image_config: azureml.core.image.image.ImageConfig
#  |      :param deployment_config: A WebserviceDeploymentConfiguration used to configure the webservice. If one is not
#  |          provided, an empty configuration object will be used based on the desired target.
#  |      :type deployment_config: WebserviceDeploymentConfiguration
#  |      :param deployment_target: A ComputeTarget to deploy the Webservice to. As ACI has no associated ComputeTarget,
#  |          leave this parameter as None to deploy to ACI.
#  |      :type deployment_target: azureml.core.compute.ComputeTarget
#  |      :return: A Webservice object corresponding to the deployed webservice
#  |      :rtype: Webservice
#  |      :raises: WebserviceException
#  |
#  |  deploy_from_image(workspace, name, image, deployment_config=None, deployment_target=None)
#  |      Deploy a Webservice from an Image object.
#  |
#  |      :param workspace: A Workspace object to associate the Webservice with
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param name: The name to give the deployed workspace. Must be unique to the workspace.
#  |      :type name: str
#  |      :param image: An Image object to deploy.
#  |      :type image: azureml.core.image.image.Image
#  |      :param deployment_config: A WebserviceDeploymentConfiguration used to configure the webservice. If one is not
#  |          provided, an empty configuration object will be used based on the desired target.
#  |      :type deployment_config: WebserviceDeploymentConfiguration
#  |      :param deployment_target: A ComputeTarget to deploy the Webservice to. As ACI has no associated ComputeTarget,
#  |          leave this parameter as None to deploy to ACI.
#  |      :type deployment_target: azureml.core.compute.ComputeTarget
#  |      :return: A Webservice object corresponding to the deployed webservice
#  |      :rtype: Webservice
#  |      :raises: WebserviceException
#  |
#  |  deploy_from_model(workspace, name, models, image_config, deployment_config=None, deployment_target=None)
#  |      Deploy a Webservice from zero or more model objects. This will create an image in the process, associated with
#  |      the specified Workspace.
#  |
#  |      :param workspace: A Workspace object to associate the Webservice with
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param name: The name to give the deployed workspace. Must be unique to the workspace.
#  |      :type name: str
#  |      :param models: A list of model objects. Can be an empty list.
#  |      :type models: list[str]
#  |      :param image_config: An ImageConfig object used to determine required Image properties.
#  |      :type image_config: azureml.core.image.image.ImageConfig
#  |      :param deployment_config: A WebserviceDeploymentConfiguration used to configure the webservice. If one is not
#  |          provided, an empty configuration object will be used based on the desired target.
#  |      :type deployment_config: WebserviceDeploymentConfiguration
#  |      :param deployment_target: A ComputeTarget to deploy the Webservice to. As ACI has no associated ComputeTarget,
#  |          leave this parameter as None to deploy to ACI.
#  |      :type deployment_target: azureml.core.compute.ComputeTarget
#  |      :return: A Webservice object corresponding to the deployed webservice
#  |      :rtype: Webservice
#  |      :raises: WebserviceException
#  |
#  |  list(workspace, compute_type=None, image_name=None, image_id=None, model_name=None, model_id=None, tags=None, properties=None)
#  |      List the Webservices associated with the corresponding Workspace. Can be filtered with specific parameters.
#  |
#  |      :param workspace: The Workspace object to list the Webservices in.
#  |      :type workspace: azureml.core.workspace.Workspace
#  |      :param compute_type: Filter to list only specific Webservice types. Options are 'ACI', 'AKS'.
#  |      :type compute_type: str
#  |      :param image_name: Filter list to only include Webservices deployed with the specific image name
#  |      :type image_name: str
#  |      :param image_id: Filter list to only include Webservices deployed with the specific image id
#  |      :type image_id: str
#  |      :param model_name: Filter list to only include Webservices deployed with the specific model name
#  |      :type model_name: str
#  |      :param model_id: Filter list to only include Webservices deployed with the specific model id
#  |      :type model_id: str
#  |      :param tags: Will filter based on the provided list, by either 'key' or '[key, value]'.
#  |          Ex. ['key', ['key2', 'key2 value']]
#  |      :type tags: list[str and/or list[str, str]]
#  |      :param properties: Will filter based on the provided list, by either 'key' or '[key, value]'.
#  |          Ex. ['key', ['key2', 'key2 value']]
#  |      :type properties: list[str and/or list[str, str]]
#  |      :return: A filtered list of Webservices in the provided Workspace
#  |      :rtype: list[Webservice]
#  |      :raises: WebserviceException
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from abc.ABC:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
image
# Out:
# ContainerImage(workspace=<azureml.core.workspace.Workspace object at 0x7fa5c417c5c0>, name=myimage12, id=myimage12:1, tags={'name': 'AKS', 'project': 'AML'}, properties={}, version=1)

# %%
# %%time
aks_service_name ='yanz-aks-service-15'

aks_service = Webservice.deploy_from_image(workspace = ws, 
                                           name = aks_service_name,
                                           image = image,
                                           deployment_config = aks_config,
                                           deployment_target = aks_target)
aks_service.wait_for_deployment(show_output = True)
print(aks_service.state)
# Out:
# Creating service
# Running......................................................................................................................
# TimedOutAKS service creation operation finished, operation "TimedOut"
# Transitioning
# CPU times: user 2.14 s, sys: 146 ms, total: 2.29 s
# Wall time: 10min 19s

# %% [markdown]
# <a id='test_ws'></a>
# ## Test Web Service¶
# We test the web sevice by passing data.

# %%
from io import BytesIO
from PIL import Image, ImageOps
import base64
import json

img_path = test_image_path
encoded = None
with open(img_path, 'rb') as file:
  encoded = base64.b64encode(file.read())
img_dict = {img_path: encoded.decode('utf-8')}
body = json.dumps(img_dict)
resp = aks_service.run(input_data = body)
print(resp)
# Out:
# ---------------------------------------------------------------------------
# WebserviceException                       Traceback (most recent call last)
# <ipython-input-18-7d6adaae75a8> in <module>
#      10 img_dict = {img_path: encoded.decode('utf-8')}
#      11 body = json.dumps(img_dict)
# ---> 12 resp = aks_service.run(input_data = body)
#      13 print(resp)
#
# /opt/conda/envs/py3.6/lib/python3.6/site-packages/azureml/core/webservice/aks.py in run(self, input_data)
#     330                                       'Response Code: {}\n'
#     331                                       'Headers: {}\n'
# --> 332                                       'Content: {}'.format(resp.status_code, resp.headers, resp.content))
#     333
#     334     def update(self, image=None, autoscale_enabled=None, autoscale_min_replicas=None, autoscale_max_replicas=None,
#
# WebserviceException: Received bad response from service:
# Response Code: 404
# Headers: {'server': 'Cowboy', 'date': 'Mon, 05 Nov 2018 13:59:17 GMT', 'content-length': '9', 'cache-control': 'max-age=0, private, must-revalidate', 'x-ms-request-id': 'd8457edd-03d3-4ccf-a21e-d0e7bf8ad51c'}
# Content: b'Not found'

# %%
aks_service.update(enable_app_insights=True)

# %%
print(aks_service.state)
# Out:
# Transitioning

# %%
aks_service.update_deployment_state()

# %%
# !kubectl --kubeconfig config_cpuaks proxy --port 8011
# Out:
# /bin/sh: 1: kubectl: not found

# %%
log = aks_service.get_logs(5000)

# %%
with open("servicelog_ws14", "w") as json_file:
    json_file.write(log)

# %%
#debug web service failure
print(ws.webservices()['yanz-aks-service-11'].get_logs())
# Out:
# {"timestamp": "2018-11-01T10:32:31.167424Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:31 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:32.167302Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:32 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:33.167403Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:33.764874Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:34.167430Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:34 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:35.167444Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:35 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:36.167509Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:36 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:37.167509Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:37 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:38.167408Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:38.764936Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:39.167463Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:39 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:40.167358Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:40 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:41.167411Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:41 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:42.167367Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:42 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:43.167420Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:43.764923Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:44.167389Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:44 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:45.167430Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:45 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:46.167471Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:46 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:47.167526Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:47 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:48.167395Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:48.764860Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:49.167465Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:49 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:50.167397Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:50 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:51.167421Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:51 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:52.167302Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:52 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:53.167406Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:53.764907Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:54.167553Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:54 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:55.167456Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:55 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:56.167415Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:56 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:57.167443Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:57 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:58.167415Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:58 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:58.764932Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:58 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:32:59.167373Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:32:59 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:00.167431Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:00 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:01.167397Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:01 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:02.167360Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:02 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:03.167357Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:03 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:03.764893Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:03 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:04.167408Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:04 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:05.167513Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:05 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:06.167410Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:06 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:07.167436Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:07 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:08.167384Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:08 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:08.764953Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:08 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:09.167511Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:09 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:10.167413Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:10 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:11.167430Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:11 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:12.167345Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:12 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:13.167397Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:13 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:13.764925Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:13 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:14.167362Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:14 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:15.167552Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:15 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:16.167477Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:16 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:17.167445Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:17 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:18.167440Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:18 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:18.764913Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:18 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:19.167435Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:19 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:20.167407Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:20 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:21.167462Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:21 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:22.167364Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:22 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:23.167408Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:23 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:23.764942Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:23 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:24.167407Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:24 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:25.167403Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:25 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:26.167434Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:26 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:27.167452Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:27 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:28.167459Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:28 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:28.764910Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:28 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:29.167380Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:29 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:30.167416Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:30 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:31.167400Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:31 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:32.167331Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:32 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:33.167410Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:33.764920Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:34.167554Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:34 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:35.167466Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:35 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:36.167377Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:36 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:37.167410Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:37 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:38.167398Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:38.764994Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:39.167465Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:39 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:40.167430Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:40 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:41.167378Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:41 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:42.167320Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:42 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:43.167362Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:43.764931Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:44.167348Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:44 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:45.167492Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:45 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:46.167393Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:46 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:47.167436Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:47 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:48.167404Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:48.764784Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:49.167415Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:49 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:50.167425Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:50 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:51.167408Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:51 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:52.167336Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:52 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:53.167382Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:53.764933Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:54.167490Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:54 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:55.167434Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:55 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:56.167454Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:56 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:57.167439Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:57 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:58.167456Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:58 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:58.764913Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:58 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:33:59.167406Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:33:59 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:00.167405Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:00 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:01.167391Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:01 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:02.167349Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:02 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:03.167385Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:03 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:03.764998Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:03 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:04.167384Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:04 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:05.167422Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:05 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T10:34:06.167440Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:10:34:06 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# ...
# {"timestamp": "2018-11-01T11:41:26.167362Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:26 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:27.167393Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:27 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:28.167400Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:28 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:28.764962Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:28 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:29.167190Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:29 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:30.167497Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:30 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:31.167443Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:31 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:32.167322Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:32 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:33.167411Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:33.764910Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:33 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:34.167375Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:34 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:35.167461Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:35 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:36.167366Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:36 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:37.167414Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:37 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:38.167451Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:38.764889Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:38 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:39.167376Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:39 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:40.167583Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:40 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:41.167398Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:41 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:42.167345Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:42 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:43.167418Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:43.764918Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:43 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:44.167284Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:44 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:45.167369Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:45 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:46.167381Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:46 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:47.167454Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:47 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:48.167419Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:48.764850Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:48 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:49.167267Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:49 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:50.167455Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:50 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:51.167415Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:51 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:52.167383Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:52 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:53.167386Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:53.764983Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:53 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:54.167417Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:54 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:55.167463Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:55 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:56.167361Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:56 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}
# {"timestamp": "2018-11-01T11:41:57.167422Z", "path": "/home/mmlspark/lib/conda/lib/python3.5/site-packages/gunicorn/glogging.py", "level": "INFO", "logger": "gunicorn.access", "tags": "%(module)s, %(asctime)s, %(levelname)s, %(message)s", "message": "127.0.0.1 - - [01/Nov/2018:11:41:57 +0000] \"GET / HTTP/1.0\" 200 7 \"-\" \"kube-probe/1.11\"", "stack_info": null, "host": "yanz-aks-service-11-795577b6f-8dlq6"}

# %% [markdown]
# <a id='clean_up'></a>
# ## Clean Up Resources

# %%
#clean up resources
#aks_target = AksCompute(name='jaya-aks-1',workspace=ws)
#aks_target.delete()

# %%
#alternate code to clean up resources
#!az aks delete --resource-group jayavienna --name jaya-aks-2 --yes

# %%
#for s in ws.webservices():
#    print(s.name)

# %%
#s =  Webservice(ws, 'jaya-aks-service-2')
#s.delete()

# %%
#from azureml.core import Workspace
#from azureml.core.compute import AksCompute, ComputeTarget

#ws = Workspace.from_config()

#for c in ws.compute_targets():
#    print(c.name)
